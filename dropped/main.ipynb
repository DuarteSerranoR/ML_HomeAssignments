# %% [markdown]
# Imports (and functions)

# %%
import numpy as np
import pandas as pd
#rom validation import *

# %% [markdown]
# # Objective 1
# ## Obj.: Regression model to predict Motor_UPDRS

# %% [markdown]
# ## 1.1. Dataset preparation
# ### 1.1.1. Split into training, dev and IVS
# - `train_df` -- training set for model training/selection
# - `dev_df` -- set for selection of the best model, with continuous validation throughout training
# - `ivs_df` / `test_df` -- independet validation set (IVS) for the final benchmark

# %%
ivs_ratio = 0.1
df = pd.read_csv("parkinsons_updrs.data")
train_size = len(df.values) * ( 1 - ivs_ratio )
df_train = df[:train_size]
df_ivs = df[train_size:]

# %% [markdown]
# ### 1.1.2. Analyzing the Data Correlation

# %%
columns = list(df.columns.values)
print(columns)
x_columns = columns[6:]
for x_col in x_columns:
    df.plot.scatter(x=x_col, y="motor_UPDRS")
# Out:
# ['subject#', 'age', 'sex', 'test_time', 'motor_UPDRS', 'total_UPDRS', 'Jitter(%)', 'Jitter(Abs)', 'Jitter:RAP', 'Jitter:PPQ5', 'Jitter:DDP', 'Shimmer', 'Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'Shimmer:APQ11', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'PPE']

# %% [markdown]
# ### 1.1.3. Setting up X and Y

# %%
x_np = np.array(df_train[['Jitter(Abs)', 'Shimmer', 'NHR', 'HNR', 'RPDE', 'DFA', 'PPE']])
y_np = np.array(df_ivs["motor_UPDRS"])

# %% [markdown]
# ## 1.2. Model Selection

# %%
from validation import CrossValidationMethods, ModelTypes


model_selection(ModelTypes.regression, CrossValidationMethods.n_fold,"RVE",x=x_np, y=y_np,
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\rapos\OneDrive\Desktop\ML_HomeAssignment1\main.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rapos/OneDrive/Desktop/ML_HomeAssignment1/main.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> model_selection(ModelTypes.regression)
#       <a href='vscode-notebook-cell:/c%3A/Users/rapos/OneDrive/Desktop/ML_HomeAssignment1/main.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> model_selection(ModelTypes.regression)
#       <a href='vscode-notebook-cell:/c%3A/Users/rapos/OneDrive/Desktop/ML_HomeAssignment1/main.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> model_selection(ModelTypes.regression)
#
# NameError: name 'model_selection' is not defined
